# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

x = np.array([20, 23, 24, 30, 33, 35]).reshape((-1, 1))
y = np.array([100000, 120000, 150000, 240000, 250000, 260000])

plt.scatter(x, y);
plt.title('My beautifull data')
plt.xlabel('age')
plt.ylabel('revenue')
plt.show()

# %%
model = LinearRegression().fit(x, y) 

print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")

y_pred = model.predict([[21]])
print('Predicted response:', y_pred, sep='\n')


xfit = np.linspace(20, 40, 1000)
yfit = model.predict(xfit[:, np.newaxis])
plt.scatter(x, y)
plt.plot(xfit, yfit);
plt.show()
# Out:
# intercept: -133030.30303030295
# slope: [11625.34435262]
# Predicted response:
# [111101.92837466]
